# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plot.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/geometry_plots/poloidal_plane.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/geometry_plots/toroidal_plane.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/arc_flux_1e4p.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/arc_tbr_1e4p.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/arc_absorption_1e3p.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()

# %%
# Path to your image file
img_path = '/home/awhitesides3/openmc/build/bin/fusion/FLIBE/openmc-scripts/arc-1/geometry_plots/arc_heating_1e4p.png'
# Load and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')  # Optional: Hide axes
plt.show()
